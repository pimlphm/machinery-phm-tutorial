# %% [markdown]
# # Colab Demo
#
# This notebook demonstrates how to use the tools in this repository on Google Colab.

# %% [markdown]
# ## Setup

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Import modules

# %%
from scripts.data_processing_tools import preprocessing
from scripts.signal_processing_tools import fft_features
from scripts.visualization_tools import plot_utils
from scripts.ml_tools import random_forest
import scripts.utils as utils
print('Modules imported')

# %% [markdown]
# ## Example operation

# %%
print('Run your tool functions here')
